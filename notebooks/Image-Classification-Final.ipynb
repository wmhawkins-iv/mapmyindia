# %%
# import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install numpy==1.15.4 --user
# !{sys.executable} -m pip install keras==2.1.3 --user
# !{sys.executable} -m pip install pandas==0.23.4 --user
# !{sys.executable} -m pip install scikit-image==0.14.1 --user
# !{sys.executable} -m pip install scikit-learn==0.19.0 --user
# !{sys.executable} -m pip install tensorflow --user

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import keras
import skimage
import tensorflow
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AvgPool2D, BatchNormalization, Reshape
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import skimage.morphology as morp
from skimage.filters import rank

# %matplotlib inline

assert pd.__version__ == '0.23.4'
assert np.__version__ == '1.15.4'
assert keras.__version__ == '2.1.3'
assert skimage.__version__ == '0.14.1'
assert sklearn.__version__ == '0.19.2'
assert tensorflow.__version__ == '1.12.0'
# Out:
# Using TensorFlow backend.

# %%
# Load all images

import os
import skimage.data
def load_data(data_dir):
    images = []
    
    file_names = sorted([os.path.join(data_dir, f)
                  for f in os.listdir(data_dir) if f.endswith(".jpg")])
    
    for f in file_names:
        images.append(skimage.data.imread(f, as_gray=True))
    
    return images

images = load_data('../data/train/cropped')
print(len(images))
# Out:
# 467

# %%
# Explore shapes
for image in images[:3]:
    print('image.shape[before]', image.shape)
# Out:
# image.shape[before] (24, 17)
# image.shape[before] (60, 45)
# image.shape[before] (148, 95)

# %%
# Transform all images to 250x250

import skimage.transform
image_size = 64
images_transformed = [skimage.transform.resize(image, (image_size, image_size)) for image in images]

# Confirm transformation shape
for image in images_transformed[:3]:
    print('image.shape[after]', image.shape)
# Out:
# image.shape[after] (64, 64)
# image.shape[after] (64, 64)
# image.shape[after] (64, 64)

# %%
from PIL import Image

for image in images_transformed[:3]:
    image = (image * 255).astype(np.uint8)
    im = Image.fromarray(image)
    plt.figure()
    plt.imshow(im)
    plt.show()

# %%
# Load Labels 
data = pd.read_csv("../data/train.csv")
data = data.sort_values("Img_Name").reset_index(drop=True)
labels = data["Label"]

labels.head()
# Out:
# 0    Speed Limit 60
# 1    Speed Limit 40
# 2    Speed Limit 20
# 3    Speed Limit 40
# 4    Speed Limit 50
# Name: Label, dtype: object

# %%
# Categorize labels..
import numpy as np
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

y = np.array(labels)
X = np.array(images_transformed)
X = X[:, :, :, np.newaxis]   # (250,250) --> (467,250,250,1)

num_categories = 6
label_encoder = LabelEncoder()
y_labels_encoded = label_encoder.fit_transform(y)
y_labels_categorized = to_categorical(y_labels_encoded, num_categories)

print('len(X)', len(X))
print('len(y)', len(y))
print('len(y_labels_categorized)', len(y_labels_categorized))
# Out:
# len(X) 467
# len(y) 467
# len(y_labels_categorized) 467

# %%
# 80/20 Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_labels_categorized, test_size=0.2, random_state=42)

# %%
# BASELINE MODEL -- Feedforward network
model = Sequential()
model.add(Flatten(input_shape=(image_size,image_size,1)))
model.add(Dense(units=image_size,activation="relu"))
model.add(Dense(units=image_size,activation="relu"))
model.add(Dense(units=6,activation="softmax"))
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
# %time model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=0)
# Out:
# CPU times: user 7.08 s, sys: 1.02 s, total: 8.1 s
# Wall time: 3.37 s

# %%
# Feedforward model accuracy
accuracy = model.evaluate(x=X_test,y=y_test,batch_size=32, verbose=0)
print("Accuracy:", round(accuracy[1],4))
print("Loss:", round(accuracy[0],4))
# Out:
# Accuracy: 0.3298
# Loss: 1.6874

# %%
# FINAL MODEL -- Convolutional NN with Pooling and Dropout
total_epochs_trained = 0
epoch_acc = []
epoch_loss = []

model = Sequential()
model.add(Conv2D(32, (5, 5), input_shape=(image_size,image_size,1), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop', #opt
              metrics=['accuracy']) 

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                200720
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 102
# =================================================================
# Total params: 220,150
# Trainable params: 220,150
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ### Validate ImageDataGenerator parameters

# data_gen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=True,
#     rotation_range=20,
#     zoom_range=0.2,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=False,
#     fill_mode="nearest",
#     channel_shift_range=0.3,
# )

# data_gen.fit(X_train)

# os.makedirs('../data/image_data_gen')
# i = 0
# for X_batch, y_batch in data_gen.flow(X_train, y_train, batch_size=5, save_to_dir='../data/image_data_gen', save_prefix='aug', save_format='jpg'):
#     i += 1
#     if i == 500:
#         break

# print("done.")

# %%
# Data augmentation on training set
train_gen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    fill_mode="nearest",
    channel_shift_range=0.3,
)

train_gen.fit(X_train)

# %%
# Fit CNN model and track loss/acc over each epoch
epochs_per_round = 1
print("ACCURACY AFTER X EPOCHS:\n")
for i in range(150):
    # Fits the model on batches with real-time data augmentation:
    model.fit_generator(
        train_gen.flow(X_train, y_train, batch_size=32),
        steps_per_epoch=len(X_train) / 32, 
        epochs=epochs_per_round,
        verbose=0
    )
    
    total_epochs_trained += epochs_per_round

    test_acc = model.evaluate(x=X_test,y=y_test,batch_size=32, verbose=0)
    train_acc = model.evaluate(x=X_train,y=y_train,batch_size=32, verbose=0)
    epoch_acc.append((test_acc[1], train_acc[1], total_epochs_trained))
    epoch_loss.append((test_acc[0], train_acc[0], total_epochs_trained))

    print("EPOCH #", total_epochs_trained, "(loss, acc):", (round(test_acc[0],3), round(test_acc[1],3)))

    
print('done.')
# Out:
# ACCURACY AFTER X EPOCHS:
#
# EPOCH # 1 (loss, acc): (1.783, 0.191)
# EPOCH # 2 (loss, acc): (1.78, 0.191)
# EPOCH # 3 (loss, acc): (1.777, 0.191)
# EPOCH # 4 (loss, acc): (1.788, 0.191)
# EPOCH # 5 (loss, acc): (1.779, 0.191)
# EPOCH # 6 (loss, acc): (1.77, 0.191)
# EPOCH # 7 (loss, acc): (1.776, 0.191)
# EPOCH # 8 (loss, acc): (1.763, 0.191)
# EPOCH # 9 (loss, acc): (1.764, 0.191)
# EPOCH # 10 (loss, acc): (1.758, 0.191)
# EPOCH # 11 (loss, acc): (1.946, 0.191)
# EPOCH # 12 (loss, acc): (1.755, 0.191)
# EPOCH # 13 (loss, acc): (1.749, 0.191)
# EPOCH # 14 (loss, acc): (1.751, 0.191)
# EPOCH # 15 (loss, acc): (1.746, 0.202)
# EPOCH # 16 (loss, acc): (1.743, 0.191)
# EPOCH # 17 (loss, acc): (1.738, 0.213)
# EPOCH # 18 (loss, acc): (1.745, 0.191)
# EPOCH # 19 (loss, acc): (1.749, 0.191)
# EPOCH # 20 (loss, acc): (1.733, 0.255)
# EPOCH # 21 (loss, acc): (1.724, 0.213)
# EPOCH # 22 (loss, acc): (1.749, 0.191)
# EPOCH # 23 (loss, acc): (1.724, 0.245)
# EPOCH # 24 (loss, acc): (1.758, 0.266)
# EPOCH # 25 (loss, acc): (1.714, 0.266)
# EPOCH # 26 (loss, acc): (1.747, 0.213)
# EPOCH # 27 (loss, acc): (1.713, 0.33)
# EPOCH # 28 (loss, acc): (1.725, 0.202)
# EPOCH # 29 (loss, acc): (1.724, 0.191)
# EPOCH # 30 (loss, acc): (1.717, 0.266)
# EPOCH # 31 (loss, acc): (1.7, 0.287)
# EPOCH # 32 (loss, acc): (1.737, 0.213)
# EPOCH # 33 (loss, acc): (1.674, 0.362)
# EPOCH # 34 (loss, acc): (1.676, 0.394)
# EPOCH # 35 (loss, acc): (1.678, 0.372)
# EPOCH # 36 (loss, acc): (1.667, 0.33)
# EPOCH # 37 (loss, acc): (1.63, 0.394)
# EPOCH # 38 (loss, acc): (1.64, 0.33)
# EPOCH # 39 (loss, acc): (1.644, 0.415)
# EPOCH # 40 (loss, acc): (1.615, 0.309)
# EPOCH # 41 (loss, acc): (1.607, 0.33)
# EPOCH # 42 (loss, acc): (1.583, 0.362)
# EPOCH # 43 (loss, acc): (1.625, 0.362)
# EPOCH # 44 (loss, acc): (1.555, 0.447)
# EPOCH # 45 (loss, acc): (1.598, 0.404)
# EPOCH # 46 (loss, acc): (1.536, 0.479)
# EPOCH # 47 (loss, acc): (1.57, 0.372)
# EPOCH # 48 (loss, acc): (1.505, 0.489)
# EPOCH # 49 (loss, acc): (1.524, 0.436)
# EPOCH # 50 (loss, acc): (1.512, 0.489)
# EPOCH # 51 (loss, acc): (1.506, 0.479)
# EPOCH # 52 (loss, acc): (1.48, 0.468)
# EPOCH # 53 (loss, acc): (1.482, 0.479)
# EPOCH # 54 (loss, acc): (1.457, 0.457)
# EPOCH # 55 (loss, acc): (1.449, 0.5)
# EPOCH # 56 (loss, acc): (1.434, 0.532)
# EPOCH # 57 (loss, acc): (1.433, 0.468)
# EPOCH # 58 (loss, acc): (1.419, 0.532)
# EPOCH # 59 (loss, acc): (1.356, 0.521)
# EPOCH # 60 (loss, acc): (1.408, 0.511)
# EPOCH # 61 (loss, acc): (1.382, 0.5)
# EPOCH # 62 (loss, acc): (1.363, 0.521)
# EPOCH # 63 (loss, acc): (1.35, 0.521)
# EPOCH # 64 (loss, acc): (1.321, 0.521)
# EPOCH # 65 (loss, acc): (1.281, 0.553)
# EPOCH # 66 (loss, acc): (1.3, 0.521)
# EPOCH # 67 (loss, acc): (1.32, 0.468)
# EPOCH # 68 (loss, acc): (1.254, 0.543)
# EPOCH # 69 (loss, acc): (1.272, 0.511)
# EPOCH # 70 (loss, acc): (1.254, 0.511)
# EPOCH # 71 (loss, acc): (1.21, 0.543)
# EPOCH # 72 (loss, acc): (1.226, 0.532)
# EPOCH # 73 (loss, acc): (1.167, 0.521)
# EPOCH # 74 (loss, acc): (1.164, 0.521)
# EPOCH # 75 (loss, acc): (1.22, 0.5)
# EPOCH # 76 (loss, acc): (1.146, 0.543)
# EPOCH # 77 (loss, acc): (1.195, 0.511)
# EPOCH # 78 (loss, acc): (1.15, 0.553)
# EPOCH # 79 (loss, acc): (1.143, 0.553)
# EPOCH # 80 (loss, acc): (1.144, 0.532)
# EPOCH # 81 (loss, acc): (1.118, 0.564)
# EPOCH # 82 (loss, acc): (1.161, 0.543)
# EPOCH # 83 (loss, acc): (1.208, 0.585)
# EPOCH # 84 (loss, acc): (1.122, 0.532)
# EPOCH # 85 (loss, acc): (1.141, 0.532)
# EPOCH # 86 (loss, acc): (1.113, 0.553)
# EPOCH # 87 (loss, acc): (1.112, 0.521)
# EPOCH # 88 (loss, acc): (1.145, 0.511)
# EPOCH # 89 (loss, acc): (1.082, 0.574)
# EPOCH # 90 (loss, acc): (1.118, 0.574)
# EPOCH # 91 (loss, acc): (1.068, 0.585)
# EPOCH # 92 (loss, acc): (1.107, 0.585)
# EPOCH # 93 (loss, acc): (1.042, 0.596)
# EPOCH # 94 (loss, acc): (1.041, 0.553)
# EPOCH # 95 (loss, acc): (1.008, 0.553)
# EPOCH # 96 (loss, acc): (1.019, 0.564)
# EPOCH # 97 (loss, acc): (1.039, 0.543)
# EPOCH # 98 (loss, acc): (1.064, 0.574)
# EPOCH # 99 (loss, acc): (1.057, 0.553)
# EPOCH # 100 (loss, acc): (1.044, 0.649)
# EPOCH # 101 (loss, acc): (0.984, 0.606)
# EPOCH # 102 (loss, acc): (1.04, 0.628)
# EPOCH # 103 (loss, acc): (1.003, 0.574)
# EPOCH # 104 (loss, acc): (1.041, 0.628)
# EPOCH # 105 (loss, acc): (0.948, 0.638)
# EPOCH # 106 (loss, acc): (0.984, 0.606)
# EPOCH # 107 (loss, acc): (0.967, 0.649)
# EPOCH # 108 (loss, acc): (1.038, 0.638)
# EPOCH # 109 (loss, acc): (0.968, 0.553)
# EPOCH # 110 (loss, acc): (0.977, 0.628)
# EPOCH # 111 (loss, acc): (0.934, 0.67)
# EPOCH # 112 (loss, acc): (0.935, 0.617)
# EPOCH # 113 (loss, acc): (0.949, 0.606)
# EPOCH # 114 (loss, acc): (1.011, 0.649)
# EPOCH # 115 (loss, acc): (0.983, 0.617)
# EPOCH # 116 (loss, acc): (0.992, 0.638)
# EPOCH # 117 (loss, acc): (0.903, 0.691)
# EPOCH # 118 (loss, acc): (0.936, 0.67)
# EPOCH # 119 (loss, acc): (0.944, 0.596)
# EPOCH # 120 (loss, acc): (0.917, 0.596)
# EPOCH # 121 (loss, acc): (0.972, 0.67)
# EPOCH # 122 (loss, acc): (0.907, 0.649)
# EPOCH # 123 (loss, acc): (0.947, 0.67)
# EPOCH # 124 (loss, acc): (0.912, 0.681)
# EPOCH # 125 (loss, acc): (0.901, 0.649)
# EPOCH # 126 (loss, acc): (0.973, 0.628)
# EPOCH # 127 (loss, acc): (0.91, 0.702)
# EPOCH # 128 (loss, acc): (0.896, 0.638)
# EPOCH # 129 (loss, acc): (0.915, 0.66)
# EPOCH # 130 (loss, acc): (0.912, 0.691)
# EPOCH # 131 (loss, acc): (0.904, 0.628)
# EPOCH # 132 (loss, acc): (0.802, 0.755)
# EPOCH # 133 (loss, acc): (0.926, 0.723)
# EPOCH # 134 (loss, acc): (0.838, 0.755)
# EPOCH # 135 (loss, acc): (0.846, 0.777)
# EPOCH # 136 (loss, acc): (0.896, 0.681)
# EPOCH # 137 (loss, acc): (0.869, 0.755)
# EPOCH # 138 (loss, acc): (0.861, 0.755)
# EPOCH # 139 (loss, acc): (0.84, 0.755)
# EPOCH # 140 (loss, acc): (0.818, 0.755)
# EPOCH # 141 (loss, acc): (0.838, 0.766)
# EPOCH # 142 (loss, acc): (0.815, 0.755)
# EPOCH # 143 (loss, acc): (0.929, 0.67)
# EPOCH # 144 (loss, acc): (0.848, 0.713)
# EPOCH # 145 (loss, acc): (0.855, 0.723)
# EPOCH # 146 (loss, acc): (0.874, 0.755)
# EPOCH # 147 (loss, acc): (0.875, 0.734)
# EPOCH # 148 (loss, acc): (0.931, 0.745)
# EPOCH # 149 (loss, acc): (1.054, 0.691)
# EPOCH # 150 (loss, acc): (0.824, 0.766)
# done.

# %%
# Visualize accuracy on train/test set over time
test_acc, train_acc, total_epochs_trained = zip(*epoch_acc)

plt.figure(figsize=(8, 6))
plt.plot(total_epochs_trained, train_acc)
plt.plot(total_epochs_trained, test_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Visualize loss on train/test set over time
test_loss, train_loss, total_epochs_trained = zip(*epoch_loss)

plt.figure(figsize=(8, 6))
plt.plot(total_epochs_trained, train_loss)
plt.plot(total_epochs_trained, test_loss)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
accuracy = model.evaluate(x=X_test,y=y_test,batch_size=32,verbose=0)
print("Accuracy:", round(accuracy[1],4))
print("Loss:", round(accuracy[0],4))
# Out:
# Accuracy: 0.766
# Loss: 0.8238

# %%
predictions = model.predict(X_test)
print('First prediction:', predictions[0])

predict_max = [max(class_probs) for class_probs in predictions]
print('Average predicted class probability:', np.mean(predict_max))

correct = [1 if np.argmax(predictions[i])==np.argmax(y_test[i]) else 0 for i in range(len(y_test))]
print("%-correct: ", np.mean(correct))
# Out:
# First prediction: [0.10676467 0.1387181  0.07771064 0.49251285 0.10225871 0.08203498]
# Average predicted class probability: 0.6637123
# %-correct:  0.7659574468085106
