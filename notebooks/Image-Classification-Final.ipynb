# %%
# import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install numpy==1.15.4 --user
# !{sys.executable} -m pip install keras==2.1.3 --user
# !{sys.executable} -m pip install pandas==0.23.4 --user
# !{sys.executable} -m pip install scikit-image==0.14.1 --user
# !{sys.executable} -m pip install scikit-learn==0.19.0 --user
# !{sys.executable} -m pip install tensorflow --user

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import keras
import skimage
import tensorflow
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AvgPool2D, BatchNormalization, Reshape
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import skimage.morphology as morp
from skimage.filters import rank

# %matplotlib inline

assert pd.__version__ == '0.23.4'
assert np.__version__ == '1.15.4'
assert keras.__version__ == '2.1.3'
assert skimage.__version__ == '0.14.1'
assert sklearn.__version__ == '0.19.2'
assert tensorflow.__version__ == '1.12.0'
# Out:
# Using TensorFlow backend.

# %%
# Load all images

import os
import skimage.data
def load_data(data_dir):
    images = []
    
    file_names = sorted([os.path.join(data_dir, f)
                  for f in os.listdir(data_dir) if f.endswith(".jpg")])
    
    for f in file_names:
        images.append(skimage.data.imread(f, as_gray=True))
    
    return images

images = load_data('../data/train/cropped')
print(len(images))
# Out:
# 467

# %%
# Explore shapes
for image in images[:3]:
    print('image.shape[before]', image.shape)
# Out:
# image.shape[before] (24, 17)
# image.shape[before] (60, 45)
# image.shape[before] (148, 95)

# %%
# Transform all images to 250x250

import skimage.transform
image_size = 64
images_transformed = [skimage.transform.resize(image, (image_size, image_size)) for image in images]

# Confirm transformation shape
for image in images_transformed[:3]:
    print('image.shape[after]', image.shape)
# Out:
# image.shape[after] (64, 64)
# image.shape[after] (64, 64)
# image.shape[after] (64, 64)

# %%
from PIL import Image

for image in images_transformed[:3]:
    image = (image * 255).astype(np.uint8)
    im = Image.fromarray(image)
    plt.figure()
    plt.imshow(im)
    plt.show()

# %%
# Load Labels 
data = pd.read_csv("../data/train.csv")
data = data.sort_values("Img_Name").reset_index(drop=True)
labels = data["Label"]

labels.head()
# Out:
# 0    Speed Limit 60
# 1    Speed Limit 40
# 2    Speed Limit 20
# 3    Speed Limit 40
# 4    Speed Limit 50
# Name: Label, dtype: object

# %%
# Categorize labels..

import numpy as np
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

y = np.array(labels)
X = np.array(images_transformed)
X = X[:, :, :, np.newaxis]   # (250,250) --> (467,250,250,1)

num_categories = 6
label_encoder = LabelEncoder()
y_labels_encoded = label_encoder.fit_transform(y)
y_labels_categorized = to_categorical(y_labels_encoded, num_categories)

print('len(X)', len(X))
print('len(y)', len(y))
print('len(y_labels_categorized)', len(y_labels_categorized))
# Out:
# len(X) 467
# len(y) 467
# len(y_labels_categorized) 467

# %%
# 80/20 Train-test split

X_train, X_test, y_train, y_test = train_test_split(X, y_labels_categorized, test_size=0.2, random_state=42)

# %%
# BASELINE MODEL -- Feedforward network

model = Sequential()
model.add(Flatten(input_shape=(image_size,image_size,1)))
model.add(Dense(units=image_size,activation="relu"))
model.add(Dense(units=image_size,activation="relu"))
model.add(Dense(units=6,activation="softmax"))
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
# %time model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=0)
# Out:
# CPU times: user 5.54 s, sys: 1.26 s, total: 6.79 s
# Wall time: 2.22 s

# %%
accuracy = model.evaluate(x=X_test,y=y_test,batch_size=32)
accuracy
# Out:
# 94/94 [==============================] - 0s 163us/step
# [1.7168894853997738, 0.5744680927154866]

# %%
# FINAL MODEL -- Convolutional NN with Pooling and Dropout

total_epochs_trained = 0
epoch_acc = []
epoch_loss = []

model = Sequential()
model.add(Conv2D(32, (5, 5), input_shape=(image_size,image_size,1), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPool2D(pool_size=(2, 2)))
# model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop', #opt
              metrics=['accuracy']) 

# NOTE: If loss=categorical_crossentropy, 
# then 'accuracy' metrics == categorical_accruacy

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 60, 60, 32)        832
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                200720
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 102
# =================================================================
# Total params: 220,150
# Trainable params: 220,150
# Non-trainable params: 0
# _________________________________________________________________

# %%
# data_gen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=True,
#     rotation_range=20,
#     zoom_range=0.2,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=False,
#     fill_mode="nearest",
#     channel_shift_range=0.3,
# )


# # compute quantities required for featurewise normalization
# # (std, mean, and principal components if ZCA whitening is applied)
# data_gen.fit(X_train)

# # fits the model on batches with real-time data augmentation:
# # model.fit_generator(train_gen.flow(X_train, y_train, batch_size=32),
# #                     steps_per_epoch=len(X_train) / 32, epochs=20)

# import os
# os.makedirs('../data/image_data_gen')

# i = 0
# for X_batch, y_batch in data_gen.flow(X_train, y_train, batch_size=5, save_to_dir='../data/image_data_gen', save_prefix='aug', save_format='jpg'):
#     i += 1
#     if i == 500:
#         break

# print("done.")

# %%
# Data augmentation on training set

train_gen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    fill_mode="nearest",
    channel_shift_range=0.3,
)


train_gen.fit(X_train)

# %%
# Fit CNN model and track loss/acc over each epoch

epochs_per_round = 1
print("ACCURACY AFTER X EPOCHS:\n")
for i in range(150):
    # Fits the model on batches with real-time data augmentation:
    model.fit_generator(
        train_gen.flow(X_train, y_train, batch_size=32),
        steps_per_epoch=len(X_train) / 32, 
        epochs=epochs_per_round,
        verbose=0
    )
    
    total_epochs_trained += epochs_per_round

    test_acc = model.evaluate(x=X_test,y=y_test,batch_size=32, verbose=0)
    train_acc = model.evaluate(x=X_train,y=y_train,batch_size=32, verbose=0)
    print("EPOCH #", total_epochs_trained, "(loss, acc):", (round(test_acc[0],3), round(test_acc[1],3)))
    epoch_acc.append((test_acc[1], train_acc[1], total_epochs_trained))
    epoch_loss.append((test_acc[0], train_acc[0], total_epochs_trained))

    
print('done.')
# Out:
# ACCURACY AFTER X EPOCHS:
#
# EPOCH # 51 (loss, acc): (1.331, 0.596)
# EPOCH # 52 (loss, acc): (1.296, 0.574)
# EPOCH # 53 (loss, acc): (1.301, 0.628)
# EPOCH # 54 (loss, acc): (1.317, 0.543)
# EPOCH # 55 (loss, acc): (1.308, 0.574)
# EPOCH # 56 (loss, acc): (1.279, 0.606)
# EPOCH # 57 (loss, acc): (1.293, 0.585)
# EPOCH # 58 (loss, acc): (1.24, 0.574)
# EPOCH # 59 (loss, acc): (1.192, 0.617)
# EPOCH # 60 (loss, acc): (1.177, 0.585)
# EPOCH # 61 (loss, acc): (1.142, 0.638)
# EPOCH # 62 (loss, acc): (1.166, 0.617)
# EPOCH # 63 (loss, acc): (1.227, 0.564)
# EPOCH # 64 (loss, acc): (1.24, 0.585)
# EPOCH # 65 (loss, acc): (1.145, 0.606)
# EPOCH # 66 (loss, acc): (1.119, 0.617)
# EPOCH # 67 (loss, acc): (1.148, 0.617)
# EPOCH # 68 (loss, acc): (1.088, 0.681)
# EPOCH # 69 (loss, acc): (1.187, 0.617)
# EPOCH # 70 (loss, acc): (1.12, 0.649)
# EPOCH # 71 (loss, acc): (1.045, 0.638)
# EPOCH # 72 (loss, acc): (1.059, 0.628)
# EPOCH # 73 (loss, acc): (1.079, 0.649)
# EPOCH # 74 (loss, acc): (1.054, 0.649)
# EPOCH # 75 (loss, acc): (1.059, 0.649)
# EPOCH # 76 (loss, acc): (1.028, 0.67)
# EPOCH # 77 (loss, acc): (1.002, 0.67)
# EPOCH # 78 (loss, acc): (1.045, 0.67)
# EPOCH # 79 (loss, acc): (0.991, 0.681)
# EPOCH # 80 (loss, acc): (0.965, 0.67)
# EPOCH # 81 (loss, acc): (0.98, 0.638)
# EPOCH # 82 (loss, acc): (0.995, 0.628)
# EPOCH # 83 (loss, acc): (0.991, 0.649)
# EPOCH # 84 (loss, acc): (0.924, 0.702)
# EPOCH # 85 (loss, acc): (1.092, 0.596)
# EPOCH # 86 (loss, acc): (0.887, 0.681)
# EPOCH # 87 (loss, acc): (0.935, 0.681)
# EPOCH # 88 (loss, acc): (1.004, 0.628)
# EPOCH # 89 (loss, acc): (0.953, 0.638)
# EPOCH # 90 (loss, acc): (0.937, 0.67)
# EPOCH # 91 (loss, acc): (0.926, 0.691)
# EPOCH # 92 (loss, acc): (0.943, 0.723)
# EPOCH # 93 (loss, acc): (0.902, 0.734)
# EPOCH # 94 (loss, acc): (0.897, 0.681)
# EPOCH # 95 (loss, acc): (0.9, 0.713)
# EPOCH # 96 (loss, acc): (0.911, 0.67)
# EPOCH # 97 (loss, acc): (0.879, 0.734)
# EPOCH # 98 (loss, acc): (0.878, 0.777)
# EPOCH # 99 (loss, acc): (0.849, 0.755)
# EPOCH # 100 (loss, acc): (0.87, 0.723)
# EPOCH # 101 (loss, acc): (0.916, 0.702)
# EPOCH # 102 (loss, acc): (0.99, 0.66)
# EPOCH # 103 (loss, acc): (0.871, 0.713)
# EPOCH # 104 (loss, acc): (0.847, 0.745)
# EPOCH # 105 (loss, acc): (0.813, 0.723)
# EPOCH # 106 (loss, acc): (0.832, 0.777)
# EPOCH # 107 (loss, acc): (0.812, 0.809)
# EPOCH # 108 (loss, acc): (0.826, 0.745)
# EPOCH # 109 (loss, acc): (0.801, 0.723)
# EPOCH # 110 (loss, acc): (0.779, 0.723)
# EPOCH # 111 (loss, acc): (0.796, 0.745)
# EPOCH # 112 (loss, acc): (0.738, 0.766)
# EPOCH # 113 (loss, acc): (0.772, 0.755)
# EPOCH # 114 (loss, acc): (0.752, 0.819)
# EPOCH # 115 (loss, acc): (0.811, 0.734)
# EPOCH # 116 (loss, acc): (0.766, 0.766)
# EPOCH # 117 (loss, acc): (0.77, 0.809)
# EPOCH # 118 (loss, acc): (0.784, 0.777)
# EPOCH # 119 (loss, acc): (0.808, 0.723)
# EPOCH # 120 (loss, acc): (0.764, 0.723)
# EPOCH # 121 (loss, acc): (0.753, 0.798)
# EPOCH # 122 (loss, acc): (0.739, 0.798)
# EPOCH # 123 (loss, acc): (0.736, 0.83)
# EPOCH # 124 (loss, acc): (0.761, 0.809)
# EPOCH # 125 (loss, acc): (0.745, 0.84)
# EPOCH # 126 (loss, acc): (0.724, 0.819)
# EPOCH # 127 (loss, acc): (0.741, 0.777)
# EPOCH # 128 (loss, acc): (0.709, 0.83)
# EPOCH # 129 (loss, acc): (0.761, 0.819)
# EPOCH # 130 (loss, acc): (0.699, 0.809)
# EPOCH # 131 (loss, acc): (0.678, 0.809)
# EPOCH # 132 (loss, acc): (0.76, 0.755)
# EPOCH # 133 (loss, acc): (0.727, 0.809)
# EPOCH # 134 (loss, acc): (0.684, 0.84)
# EPOCH # 135 (loss, acc): (0.774, 0.777)
# EPOCH # 136 (loss, acc): (0.752, 0.766)
# EPOCH # 137 (loss, acc): (0.67, 0.819)
# EPOCH # 138 (loss, acc): (0.745, 0.787)
# EPOCH # 139 (loss, acc): (0.704, 0.798)
# EPOCH # 140 (loss, acc): (0.756, 0.755)
# EPOCH # 141 (loss, acc): (0.666, 0.862)
# EPOCH # 142 (loss, acc): (0.711, 0.851)
# EPOCH # 143 (loss, acc): (0.704, 0.798)
# EPOCH # 144 (loss, acc): (0.687, 0.862)
# EPOCH # 145 (loss, acc): (0.692, 0.83)
# EPOCH # 146 (loss, acc): (0.725, 0.819)
# EPOCH # 147 (loss, acc): (0.668, 0.872)
# EPOCH # 148 (loss, acc): (0.685, 0.851)
# EPOCH # 149 (loss, acc): (0.751, 0.819)
# EPOCH # 150 (loss, acc): (0.681, 0.83)
# EPOCH # 151 (loss, acc): (0.667, 0.851)
# EPOCH # 152 (loss, acc): (0.703, 0.84)
# EPOCH # 153 (loss, acc): (0.663, 0.851)
# EPOCH # 154 (loss, acc): (0.74, 0.766)
# EPOCH # 155 (loss, acc): (0.705, 0.798)
# EPOCH # 156 (loss, acc): (0.682, 0.84)
# EPOCH # 157 (loss, acc): (0.703, 0.787)
# EPOCH # 158 (loss, acc): (0.657, 0.862)
# EPOCH # 159 (loss, acc): (0.668, 0.84)
# EPOCH # 160 (loss, acc): (0.659, 0.84)
# EPOCH # 161 (loss, acc): (0.661, 0.862)
# EPOCH # 162 (loss, acc): (0.69, 0.851)
# EPOCH # 163 (loss, acc): (0.665, 0.798)
# EPOCH # 164 (loss, acc): (0.631, 0.872)
# EPOCH # 165 (loss, acc): (0.71, 0.809)
# EPOCH # 166 (loss, acc): (0.64, 0.84)
# EPOCH # 167 (loss, acc): (0.646, 0.851)
# EPOCH # 168 (loss, acc): (0.658, 0.809)
# EPOCH # 169 (loss, acc): (0.688, 0.851)
# EPOCH # 170 (loss, acc): (0.67, 0.819)
# EPOCH # 171 (loss, acc): (0.706, 0.83)
# EPOCH # 172 (loss, acc): (0.678, 0.787)
# EPOCH # 173 (loss, acc): (0.642, 0.851)
# EPOCH # 174 (loss, acc): (0.644, 0.84)
# EPOCH # 175 (loss, acc): (0.705, 0.84)
# EPOCH # 176 (loss, acc): (0.665, 0.809)
# EPOCH # 177 (loss, acc): (0.668, 0.798)
# EPOCH # 178 (loss, acc): (0.663, 0.798)
# EPOCH # 179 (loss, acc): (0.661, 0.84)
# EPOCH # 180 (loss, acc): (0.705, 0.787)
# EPOCH # 181 (loss, acc): (0.715, 0.787)
# EPOCH # 182 (loss, acc): (0.719, 0.766)
# EPOCH # 183 (loss, acc): (0.666, 0.787)
# EPOCH # 184 (loss, acc): (0.725, 0.755)
# EPOCH # 185 (loss, acc): (0.657, 0.862)
# EPOCH # 186 (loss, acc): (0.688, 0.819)
# EPOCH # 187 (loss, acc): (0.689, 0.819)
# EPOCH # 188 (loss, acc): (0.66, 0.84)
# EPOCH # 189 (loss, acc): (0.604, 0.862)
# EPOCH # 190 (loss, acc): (0.658, 0.819)
# EPOCH # 191 (loss, acc): (0.666, 0.851)
# EPOCH # 192 (loss, acc): (0.732, 0.787)
# EPOCH # 193 (loss, acc): (0.648, 0.851)
# EPOCH # 194 (loss, acc): (0.657, 0.84)
# EPOCH # 195 (loss, acc): (0.617, 0.84)
# EPOCH # 196 (loss, acc): (0.637, 0.851)
# EPOCH # 197 (loss, acc): (0.687, 0.819)
# EPOCH # 198 (loss, acc): (0.754, 0.766)
# EPOCH # 199 (loss, acc): (0.67, 0.809)
# EPOCH # 200 (loss, acc): (0.622, 0.84)
# [(0.19148936201917363, 0.273458445080164, 1), (0.24468085423428962, 0.30026809687429074, 2), (0.24468085360019765, 0.27077748025230686, 3), (0.20212766401311186, 0.27882037537507015, 4), (0.2659574493448785, 0.29758713172683765, 5), (0.2553191514725381, 0.25737265451504143, 6), (0.24468085360019765, 0.3324396790032732, 7), (0.2553191508384461, 0.3378016092981794, 8), (0.2553191508384461, 0.3351206434715849, 9), (0.2553191508384461, 0.3351206441507263, 10), (0.24468085296610567, 0.3351206441507263, 11), (0.28723404508955935, 0.3324396790032732, 12), (0.27659574658312697, 0.30563002700939895, 13), (0.21276596188545227, 0.3109919578236485, 14), (0.23404255699604115, 0.3458445047405386, 15), (0.27659574658312697, 0.31635388795875674, 16), (0.2659574493448785, 0.3485254698879917, 17), (0.2978723423278078, 0.37265415605527147, 18), (0.3191489374383967, 0.34048257428583445, 19), (0.2978723429618998, 0.4021447725174574, 20), (0.3297872359448291, 0.3994638073700043, 21), (0.27659574658312697, 0.37801608619037963, 22), (0.3191489374383967, 0.3833780164852858, 23), (0.3723404268000988, 0.4369973194343475, 24), (0.26595744712555663, 0.3136729229711016, 25), (0.3723404261660069, 0.41018766795981665, 26), (0.425531914893617, 0.49329758737106427, 27), (0.39361702127659576, 0.4316353889796433, 28), (0.3723404255319149, 0.4235924936970821, 29), (0.4148936176553686, 0.4825737281395347, 30), (0.425531914893617, 0.48257372678125193, 31), (0.3191489380724887, 0.36729222560056735, 32), (0.4148936176553686, 0.49329758872934704, 33), (0.425531914893617, 0.5093833780959848, 34), (0.44680851063829785, 0.5442359258917637, 35), (0.44680851063829785, 0.5415549613835026, 36), (0.28723404508955935, 0.36729222544076934, 37), (0.44680851063829785, 0.5281501341281564, 38), (0.436170221643245, 0.5281501356462371, 39), (0.46808511526026625, 0.525469170498784, 40), (0.40425531914893614, 0.4638069705892824, 41), (0.5106382978723404, 0.5576407516290292, 42), (0.4574468085106383, 0.5093833780959848, 43), (0.5319149024943088, 0.6032171594553275, 44), (0.6170212842048483, 0.6273458453030113, 45), (0.5425532003666492, 0.6246648806349522, 46), (0.5531914982389896, 0.6032171596151255, 47), (0.5425532003666492, 0.6085790897502337, 48), (0.4787234131326067, 0.5710455780054865, 49), (0.44680851951558537, 0.6112600548976868, 50), (0.5957446897283514, 0.6595174269126504, 51), (0.5744680939836705, 0.6353887412247645, 52), (0.6276595731999012, 0.6327077760773114, 53), (0.5425532003666492, 0.6112600552172827, 54), (0.574468083838199, 0.6246648807947501, 55), (0.6063829876006918, 0.6327077759175135, 56), (0.5851063817105395, 0.6407506710402767, 57), (0.5744680927154866, 0.6380697058928236, 58), (0.6170212854730323, 0.6836461130799302, 59), (0.5851063918560109, 0.6702412875024627, 60), (0.6382978710722416, 0.6970509389769936, 61), (0.6170212753275608, 0.6916890083624914, 62), (0.5638297859658586, 0.6434316363475278, 63), (0.5851063817105395, 0.6461126014949808, 64), (0.6063829774552203, 0.6943699735099444, 65), (0.6170212753275608, 0.6675603223550096, 66), (0.6170212753275608, 0.678284182944822, 67), (0.6808510714388908, 0.713136729701914, 68), (0.6170212753275608, 0.6380697058928236, 69), (0.6489361689445821, 0.7158176946895691, 70), (0.6382978710722416, 0.7104557645544609, 71), (0.6276595731999012, 0.7265415554391794, 72), (0.6489361689445821, 0.7211796249844753, 73), (0.6489361689445821, 0.6997319041244466, 74), (0.6489361689445821, 0.7050938342595547, 75), (0.6702127646892628, 0.7184986598370222, 76), (0.6702127646892628, 0.7184986598370222, 77), (0.6702127735665504, 0.6970509388171955, 78), (0.6808510625616033, 0.7399463811764448, 79), (0.6702127646892628, 0.7345844508815387, 80), (0.6382978710722416, 0.6943699741491364, 81), (0.6276595820771887, 0.7024128694316977, 82), (0.6489361676763981, 0.7292225207464305, 83), (0.7021276570381002, 0.7560321719013654, 84), (0.5957446795828799, 0.6702412879818566, 85), (0.6808510625616033, 0.7426273461641, 86), (0.6808510625616033, 0.7184 ...

# %%
# Visualize accuracy on train/test set over time
test_acc, train_acc, total_epochs_trained = zip(*epoch_acc)

plt.figure(figsize=(8, 6))
plt.plot(total_epochs_trained, train_acc)
plt.plot(total_epochs_trained, test_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Visualize loss on train/test set over time
test_loss, train_loss, total_epochs_trained = zip(*epoch_loss)

plt.figure(figsize=(8, 6))
plt.plot(total_epochs_trained, train_loss)
plt.plot(total_epochs_trained, test_loss)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
accuracy = model.evaluate(x=X_test,y=y_test,batch_size=32,verbose=0)
print("Accuracy:", round(accuracy[1],4))
print("Loss:", round(accuracy[0],4))
# Out:
# Accuracy: 0.8404
# Loss: 0.6218

# %%
predictions = model.predict(X_test)
print('First prediction:', predictions[0])

predict_max = [max(class_probs) for class_probs in predictions]
print('Average predicted class probability:', np.mean(predict_max))

correct = [1 if np.argmax(predictions[i])==np.argmax(y_test[i]) else 0 for i in range(len(y_test))]
print("%-correct: ", np.mean(correct))
# Out:
# First prediction: [0.02810316 0.09088899 0.06399721 0.47800362 0.15545255 0.1835544 ]
# Average predicted class probability: 0.77769387
# %-correct:  0.8404255319148937
